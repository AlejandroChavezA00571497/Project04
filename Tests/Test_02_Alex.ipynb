# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import pandas as pd 
df = pd.read_csv("../Resources/songAttributes_1999-2019.csv")
df.head()
# Out:
#    Unnamed: 0  Acousticness                             Album  \
# 0           0      0.000728  Collective Soul (Deluxe Version)
# 1           1      0.018200  Collective Soul (Deluxe Version)
# 2           2      0.000473  Collective Soul (Deluxe Version)
# 3           3      0.000970  Collective Soul (Deluxe Version)
# 4           4      0.000036  Collective Soul (Deluxe Version)
#
#             Artist  Danceability  Duration  Energy  Explicit  \
# 0  Collective Soul         0.520    234947   0.904     False
# 1  Collective Soul         0.581    239573   0.709     False
# 2  Collective Soul         0.572    198400   0.918     False
# 3  Collective Soul         0.596    231453   0.661     False
# 4  Collective Soul         0.520    222520   0.808     False
#
#    Instrumentalness  Liveness  Loudness  Mode               Name  Popularity  \
# 0          0.010300    0.0634    -5.030     1  Welcome All Again          35
# 1          0.000664    0.1740    -4.909     1              Fuzzy          31
# 2          0.000431    0.0977    -3.324     0                Dig          30
# 3          0.000033    0.1130    -5.051     1                You          35
# 4          0.000010    0.0800    -4.553     0            My Days          21
#
#    Speechiness    Tempo  TimeSignature  Valence
# 0       0.0309  106.022              4    0.365
# 1       0.0282  120.027              4    0.408
# 2       0.0559  144.061              4    0.370
# 3       0.0254  111.975              4    0.183
# 4       0.0318   92.721              4    0.666

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154931 entries, 0 to 154930
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        154931 non-null  int64
#  1   Acousticness      154931 non-null  float64
#  2   Album             154931 non-null  object
#  3   Artist            154931 non-null  object
#  4   Danceability      154931 non-null  float64
#  5   Duration          154931 non-null  int64
#  6   Energy            154931 non-null  float64
#  7   Explicit          154931 non-null  bool
#  8   Instrumentalness  154931 non-null  float64
#  9   Liveness          154931 non-null  float64
#  10  Loudness          154931 non-null  float64
#  11  Mode              154931 non-null  int64
#  12  Name              154931 non-null  object
#  13  Popularity        154931 non-null  int64
#  14  Speechiness       154931 non-null  float64
#  15  Tempo             154931 non-null  float64
#  16  TimeSignature     154931 non-null  int64
#  17  Valence           154931 non-null  float64
# dtypes: bool(1), float64(9), int64(5), object(3)
# memory usage: 20.2+ MB

# %%
df = df.drop(columns= ["Name", "Unnamed: 0", "Album", "Artist"])

# %%
df = pd.get_dummies(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154931 entries, 0 to 154930
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Acousticness      154931 non-null  float64
#  1   Danceability      154931 non-null  float64
#  2   Duration          154931 non-null  int64
#  3   Energy            154931 non-null  float64
#  4   Explicit          154931 non-null  bool
#  5   Instrumentalness  154931 non-null  float64
#  6   Liveness          154931 non-null  float64
#  7   Loudness          154931 non-null  float64
#  8   Mode              154931 non-null  int64
#  9   Popularity        154931 non-null  int64
#  10  Speechiness       154931 non-null  float64
#  11  Tempo             154931 non-null  float64
#  12  TimeSignature     154931 non-null  int64
#  13  Valence           154931 non-null  float64
# dtypes: bool(1), float64(9), int64(4)
# memory usage: 15.5 MB

# %%
# Split our preprocessed data into our features and target arrays
X = df.drop(columns = ["Popularity"])
y = df["Popularity"]
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_input_features = len(X_train_scaled[0])
num_neurons_hl1 = 10
num_neurons_hl2 = 10
num_neurons_hl3 = 10




nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = num_neurons_hl1, input_dim = num_input_features, activation = "relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = num_neurons_hl2, activation = "relu"))

#Third hidden layer
nn.add(tf.keras.layers.Dense(units = num_neurons_hl3, activation = "relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                140
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 371 (1.45 KB)
# Trainable params: 371 (1.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 3632/3632 [==============================] - 14s 3ms/step - loss: -9096291.0000 - accuracy: 0.0364
# Epoch 2/50
# 3632/3632 [==============================] - 10s 3ms/step - loss: -164607232.0000 - accuracy: 0.0361
# Epoch 3/50
#  255/3632 [=>............................] - ETA: 10s - loss: -383140704.0000 - accuracy: 0.0370
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Aspire-PC\OneDrive\Documentos\Data Analysis Bootcamp Tec EDX\Projects\Project04\Project04\Tests\Test_02_Alex.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Aspire-PC/OneDrive/Documentos/Data%20Analysis%20Bootcamp%20Tec%20EDX/Projects/Project04/Project04/Tests/Test_02_Alex.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # Train the model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aspire-PC/OneDrive/Documentos/Data%20Analysis%20Bootcamp%20Tec%20EDX/Projects/Project04/Project04/Tests/Test_02_Alex.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> fit_model = nn.fit(X_train_scaled, y_train, epochs = 50)
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\keras\src\engine\training.py:1774, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1772 callbacks.on_epoch_begin(epoch)
#    1773 with data_handler.catch_stop_iteration():
# -> 1774     for step in data_handler.steps():
#    1775         with tf.profiler.experimental.Trace(
#    1776             "train",
#    1777             epoch_num=epoch,
#    (...)
#    1780             _r=1,
#    1781         ):
#    1782             callbacks.on_train_batch_begin(step)
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\keras\src\engine\data_adapter.py:1411, in DataHandler.steps(self)
#    1409 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410     break
# -> 1411 original_spe = self._steps_per_execution.numpy().item()
#    1412 can_run_full_execution = (
#    1413     original_spe == 1
#    1414     or self._inferred_steps is None
#    1415     or self._inferred_steps - self._current_step >= original_spe
#    1416 )
#    1418 if can_run_full_execution:
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:687, in BaseResourceVariable.numpy(self)
#     685 def numpy(self):
#     686   if context.executing_eagerly():
# --> 687     return self.read_value().numpy()
#     688   raise NotImplementedError(
#     689       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:814, in BaseResourceVariable.read_value(self)
#     805 """Constructs an op which reads the value of this variable.
#     806
#     807 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     811   The value of the variable.
#     812 """
#     813 with ops.name_scope("Read"):
# --> 814   value = self._read_variable_op()
#     815 # Return an identity so it can get placed on whatever device the context
#     816 # specifies instead of the device where the variable is.
#     817 return array_ops.identity(value)
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:793, in BaseResourceVariable._read_variable_op(self, no_copy)
#     791       result = read_and_set_handle(no_copy)
#     792 else:
# --> 793   result = read_and_set_handle(no_copy)
#     795 if not context.executing_eagerly():
#     796   # Note that if a control flow context is active the input of the read op
#     797   # might not actually be the handle. This line bypasses it.
#     798   record.record_operation(
#     799       "ReadVariableOp", [result], [self.handle],
#     800       backward_function=lambda x: [x],
#     801       forward_function=lambda x: [x])
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:783, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     781 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     782   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 783 result = gen_resource_variable_ops.read_variable_op(
#     784     self.handle, self._dtype)
#     785 _maybe_set_handle_data(self._dtype, self.handle, result)
#     786 return result
#
# File c:\Users\Aspire-PC\anaconda3\envs\orange3\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:589, in read_variable_op(resource, dtype, name)
#     587 if tld.is_eager:
#     588   try:
# --> 589     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     590       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     591     return _result
#     592   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
