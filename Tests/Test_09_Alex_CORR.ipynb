# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_01 = pd.read_csv("../Resources/artistDf.csv")
print(df_01.info())
df_01.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   X               1035 non-null   int64
#  1   Artist          1035 non-null   object
#  2   Followers       1035 non-null   int64
#  3   Genres          1017 non-null   object
#  4   NumAlbums       1035 non-null   int64
#  5   YearFirstAlbum  1035 non-null   int64
#  6   Gender          951 non-null    object
#  7   Group.Solo      1019 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 64.8+ KB
# None
#    X          Artist  Followers                                    Genres  \
# 0  0      Ed Sheeran   52698756                                pop,uk pop
# 1  1   Justin Bieber   30711450  canadian pop,dance pop,pop,post-teen pop
# 2  2  Jonas Brothers    3069527      boy band,dance pop,pop,post-teen pop
#
#    NumAlbums  YearFirstAlbum Gender Group.Solo
# ...

# %%
clean_df_01 = df_01.drop(columns=["X","Artist","Genres"])
clean_df_01 = pd.get_dummies(clean_df_01)
clean_df_01.corr()
# Out:
#                   Followers  NumAlbums  YearFirstAlbum  Gender_F  Gender_M  \
# Followers          1.000000   0.035728        0.056516 -0.001521  0.013456
# NumAlbums          0.035728   1.000000       -0.549382 -0.104954  0.148398
# YearFirstAlbum     0.056516  -0.549382        1.000000 -0.005460 -0.045926
# Gender_F          -0.001521  -0.104954       -0.005460  1.000000 -0.811989
# Gender_M           0.013456   0.148398       -0.045926 -0.811989  1.000000
# Group.Solo_Group  -0.002944  -0.126925        0.013319 -0.253877  0.050774
# Group.Solo_Solo   -0.009408   0.136883       -0.024594  0.268578 -0.001143
#
#                   Group.Solo_Group  Group.Solo_Solo
# Followers                -0.002944        -0.009408
# NumAlbums                -0.126925         0.136883
# YearFirstAlbum            0.013319        -0.024594
# Gender_F                 -0.253877         0.268578
# Gender_M                  0.050774        -0.001143
# Group.Solo_Group          1.000000        -0.965562
# ...

# %%
df_02 = pd.read_csv("../Resources/billboardHot100_1999-2019.csv")
print(df_02.info())
df_02.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97225 entries, 0 to 97224
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       97225 non-null  int64
#  1   Artists          97225 non-null  object
#  2   Name             97225 non-null  object
#  3   Weekly.rank      97225 non-null  int64
#  4   Peak.position    90156 non-null  float64
#  5   Weeks.on.chart   90156 non-null  float64
#  6   Week             97225 non-null  object
#  7   Date             84978 non-null  object
#  8   Genre            97225 non-null  object
#  9   Writing.Credits  90012 non-null  object
#  10  Lyrics           97225 non-null  object
#  11  Features         21289 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 8.9+ MB
# None
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# ...

# %%
clean_df_02 = df_02.drop(columns=["Unnamed: 0","Artists","Name", "Genre", "Lyrics", "Writing.Credits","Features","Week","Date"])
clean_df_02 = pd.get_dummies(clean_df_02)
clean_df_02.corr()
# Out:
#                 Weekly.rank  Peak.position  Weeks.on.chart
# Weekly.rank        1.000000       0.823589       -0.323926
# Peak.position      0.823589       1.000000       -0.549217
# Weeks.on.chart    -0.323926      -0.549217        1.000000

# %%
df_03 = pd.read_csv("../Resources/grammyAlbums_199-2019.csv")
print(df_03.info())
df_03.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  935 non-null    int64
#  1   Award       935 non-null    object
#  2   GrammyYear  935 non-null    int64
#  3   Genre       935 non-null    object
#  4   Album       935 non-null    object
#  5   Artist      898 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.0+ KB
# None
#    Unnamed: 0                             Award  GrammyYear            Genre  \
# 0           0                 Album Of The Year        2018          General
# 1           1  Best Traditional Pop Vocal Album        2018  Traditional Pop
# 2           2              Best Pop Vocal Album        2018              Pop
#
#          Album           Artist
# 0  Golden Hour  Kacey Musgraves
# 1       My Way    Willie Nelson
# 2    Sweetener    Ariana Grande

# %%
clean_df_03 = df_03.drop(columns=["Unnamed: 0", "Artist", "Album"])
clean_df_03 = pd.get_dummies(clean_df_03)
clean_df_03.corr()
# Out:
#                                     GrammyYear  Award_Album Of The Year  \
# GrammyYear                            1.000000                 0.011190
# Award_Album Of The Year               0.011190                 1.000000
# Award_Best Album Notes                0.011190                -0.021858
# Award_Best Alternative Music Album    0.023885                -0.021293
# Award_Best Americana Album            0.101605                -0.015372
# ...                                        ...                      ...
# Genre_Reggae                          0.011190                -0.021858
# Genre_Rock                            0.011190                -0.021858
# Genre_Spoken Word                    -0.026735                -0.023997
# Genre_Traditional Pop                 0.023885                -0.021293
# Genre_World Music                    -0.004804                -0.025976
#
#                                     Award_Best Album Notes  \
# ...

# %%
df_04 = pd.read_csv("../Resources/grammySongs_1999-2019.csv")
print(df_04.info())
df_04.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   428 non-null    int64
#  1   X            428 non-null    int64
#  2   GrammyAward  428 non-null    object
#  3   GrammyYear   428 non-null    int64
#  4   Genre        428 non-null    object
#  5   Name         428 non-null    object
#  6   Artist       417 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 23.5+ KB
# None
#    Unnamed: 0  X                GrammyAward  GrammyYear    Genre  \
# 0           1  0         Record Of The Year        2018  General
# 1           2  1           Song Of The Year        2018  General
# 2           3  2  Best Pop Solo Performance        2018      Pop
#
#                                         Name            Artist
# 0                            this is America  Childish Gambino
# ...

# %%
clean_df_04 = df_04.drop(columns=["Unnamed: 0", "X", "Name", "Artist"])
clean_df_04 = pd.get_dummies(clean_df_04)
clean_df_04.corr()
# Out:
#                                                     GrammyYear  \
# GrammyYear                                            1.000000
# GrammyAward_Best American Roots Performance           0.140185
# GrammyAward_Best American Roots Song                  0.143510
# GrammyAward_Best Contemporary Christian Music P...    0.140185
# GrammyAward_Best Country Duo/Group Performance        0.142407
# GrammyAward_Best Country Solo Performance             0.142407
# GrammyAward_Best Country Song                         0.000355
# GrammyAward_Best Dance Recording                      0.000355
# GrammyAward_Best Female Country Vocal Performance    -0.116378
# GrammyAward_Best Female Pop Vocal Performance        -0.116378
# GrammyAward_Best Female R&B Vocal Performance        -0.116378
# GrammyAward_Best Female Rap Solo Performance         -0.070480
# GrammyAward_Best Female Rock Vocal Performance       -0.139836
# GrammyAward_Best Gospel Performance/Song              0.140185
# ...

# %%
df_05 = pd.read_csv("../Resources/riaaAlbumCerts_1999-2019.csv")
print(df_05.info())
df_05.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1731 entries, 0 to 1730
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1731 non-null   int64
#  1   Album       1731 non-null   object
#  2   Artist      1731 non-null   object
#  3   Status      1731 non-null   object
#  4   Label       1731 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 67.7+ KB
# None
#    Unnamed: 0           Album        Artist             Status  \
# 0           0   GREATEST HITS  MARIAH CAREY  2x Multi-Platinum
# 1           1     THE REMIXES  MARIAH CAREY               Gold
# 2           2           VIEWS         DRAKE  6x Multi-Platinum
#
#                                                Label
# 0                                             LEGACY
# 1                                           COLUMBIA
# 2   REPUBLIC RECORDS / CASH MONEY RECORDS / YOUNG...

# %%
clean_df_05 = df_05.drop(columns=["Unnamed: 0", "Album","Artist"])
clean_df_05 = pd.get_dummies(clean_df_05)
clean_df_05.corr()
# Out:
#                                                     Status_10x Diamond  \
# Status_10x Diamond                                            1.000000
# Status_11x Diamond                                           -0.004716
# Status_14x Diamond                                           -0.001923
# Status_18x Diamond                                           -0.001923
# Status_1x Platinum                                           -0.055668
# ...                                                                ...
# Label_ XL RECORDINGS                                         -0.002720
# Label_ XL RECORDINGS / COLUMBIA                              -0.001923
# Label_ YOUNG MONEY / CASH MONEY / REPUBLIC RECORDS           -0.005096
# Label_ YOUNG MONEY RECORDS                                   -0.001923
# Label_ ZOMBA                                                 -0.001923
#
#                                                     Status_11x Diamond  \
# ...

# %%
df_06 = pd.read_csv("../Resources/riaaSingleCerts_1999-2019.csv")
print(df_06.info())
df_06.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2601 entries, 0 to 2600
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           2601 non-null   int64
#  1   Name        2601 non-null   object
#  2   Artist      2601 non-null   object
#  3   RiaaStatus  2601 non-null   object
#  4   Label       2601 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 101.7+ KB
# None
#    X        Name        Artist   RiaaStatus  \
# 0  0  Wish Wish      Dj Khaled         Gold
# 1  1    Level Up         Ciara  1x Platinum
# 2  2  Con Calma   Daddy Yankee  11x Diamond
#
#                                         Label
# 0                          We the Best / Epic
# 1                  Beauty Marks Entertainment
# 2  Universal Music Latino / El Cartel Records

# %%
clean_df_06 = df_06.drop(columns=["X", "Name","Artist"])
clean_df_06 = pd.get_dummies(clean_df_06)
clean_df_06.corr()
# Out:
#                                  RiaaStatus_10x Diamond  \
# RiaaStatus_10x Diamond                         1.000000
# RiaaStatus_11x Diamond                        -0.003560
# RiaaStatus_12x Diamond                        -0.003183
# RiaaStatus_13x Diamond                        -0.001591
# RiaaStatus_16x Diamond                        -0.002250
# ...                                                 ...
# Label_s-Curve Records                         -0.004505
# Label_the Bicycle Music Company               -0.002250
# Label_the Orchard                             -0.001591
# Label_the Valory Music Co                     -0.006381
# Label_this is Hit, Inc                        -0.001591
#
#                                  RiaaStatus_11x Diamond  \
# RiaaStatus_10x Diamond                        -0.003560
# RiaaStatus_11x Diamond                         1.000000
# RiaaStatus_12x Diamond                        -0.001722
# RiaaStatus_13x Diamond                        -0.000861
# ...

# %%
df_07 = pd.read_csv("../Resources/songAttributes_1999-2019.csv")
print(df_07.info())
df_07.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154931 entries, 0 to 154930
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        154931 non-null  int64
#  1   Acousticness      154931 non-null  float64
#  2   Album             154931 non-null  object
#  3   Artist            154931 non-null  object
#  4   Danceability      154931 non-null  float64
#  5   Duration          154931 non-null  int64
#  6   Energy            154931 non-null  float64
#  7   Explicit          154931 non-null  bool
#  8   Instrumentalness  154931 non-null  float64
#  9   Liveness          154931 non-null  float64
#  10  Loudness          154931 non-null  float64
#  11  Mode              154931 non-null  int64
#  12  Name              154931 non-null  object
#  13  Popularity        154931 non-null  int64
#  14  Speechiness       154931 non-null  float64
#  15  Tempo             154931 non-null  float64
# ...

# %%
clean_df_07 = df_07.drop(columns=["Unnamed: 0", "Album","Artist", "Name"])
clean_df_07 = pd.get_dummies(clean_df_07)
clean_df_07.corr()
# Out:
#                   Acousticness  Danceability  Duration    Energy  Explicit  \
# Acousticness          1.000000     -0.237465 -0.163021 -0.692831 -0.161677
# Danceability         -0.237465      1.000000 -0.023899  0.129568  0.261566
# Duration             -0.163021     -0.023899  1.000000  0.114669 -0.061312
# Energy               -0.692831      0.129568  0.114669  1.000000  0.116195
# Explicit             -0.161677      0.261566 -0.061312  0.116195  1.000000
# Instrumentalness     -0.009606     -0.118227  0.126146 -0.009896 -0.131355
# Liveness              0.008735     -0.196645  0.046760  0.155784  0.030307
# Loudness             -0.567193      0.182151  0.100653  0.757341  0.107879
# Mode                  0.099790     -0.090567 -0.044574 -0.090799 -0.114226
# Popularity           -0.107450     -0.007350  0.045612  0.099233  0.000778
# Speechiness           0.000877      0.215217 -0.135556  0.039303  0.473954
# ...

# %%
df_08 = pd.read_csv("../Resources/spotifyWeeklyTop200Streams.csv")
print(df_08.info())
df_08.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26395 entries, 0 to 26394
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26395 non-null  int64
#  1   Name        26395 non-null  object
#  2   Artist      26395 non-null  object
#  3   Features    4658 non-null   object
#  4   Streams     26395 non-null  int64
#  5   Week        26395 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.2+ MB
# None
#    Unnamed: 0            Name      Artist Features   Streams        Week
# 0           0  In My Feelings       Drake      NaN  30747676  2018-07-20
# 1           1    Lucid Dreams  Juice WRLD      NaN  12930705  2018-07-20
# 2           2         Nonstop       Drake      NaN  12312859  2018-07-20

# %%
clean_df_08 = df_08.drop(columns=["Unnamed: 0", "Name","Artist"])
clean_df_08['Features'] = clean_df_08['Features'].notna()  # Converts non-NaN values to True, NaN values to False
clean_df_08['Features'] = clean_df_08['Features'].astype(bool)  # Converts True/False to boolean values
clean_df_08 = pd.get_dummies(clean_df_08)
clean_df_08.corr()
# Out:
#                  Features   Streams  Week_2016-12-30  Week_2017-01-06  \
# Features         1.000000  0.005717        -0.020966        -0.015236
# Streams          0.005717  1.000000        -0.036689        -0.036210
# Week_2016-12-30 -0.020966 -0.036689         1.000000        -0.007635
# Week_2017-01-06 -0.015236 -0.036210        -0.007635         1.000000
# Week_2017-01-13 -0.017528 -0.032479        -0.007635        -0.007635
# ...                   ...       ...              ...              ...
# Week_2019-06-07  0.003101 -0.000156        -0.007635        -0.007635
# Week_2019-06-14  0.001954 -0.002663        -0.007635        -0.007635
# Week_2019-06-21  0.004247 -0.004154        -0.007635        -0.007635
# Week_2019-06-28  0.001954  0.000895        -0.007635        -0.007635
# Week_2019-07-05  0.001954  0.002220        -0.007635        -0.007635
#
#                  Week_2017-01-13  Week_2017-01-20  Week_2017-01-27  \
# ...
